# %% [markdown]
# <a href="https://colab.research.google.com/github/1994shuklaanand/-Image-Data-Scraping/blob/main/Image_Data_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/16R4pSOyZDiyEXM2nIRRranCrBlR724tT?usp=sharing)

# %% [markdown]
# ##Install and import the library

# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

# %% [markdown]
# ##Set ur directory

# %%
#set the directory

dir = '/content/drive/MyDrive/image dataset'

# %% [markdown]
# ##Download The Image

# %%
downloader.download('tiger animal', limit = 50, output_dir = dir, adult_filter_off = False)
# Out:
# [%] Downloading Images to /content/drive/MyDrive/image dataset/tiger animal
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://images4.fanpop.com/image/photos/20200000/Tigers-animals-20238015-2493-1983.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://4.bp.blogspot.com/-CKOjr2gjZvw/UOJx0c5DsiI/AAAAAAAABfs/QI1ENNk2UDo/s1600/Tigers,+4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://4.bp.blogspot.com/-hTsjXMC76vA/TwwiR5D4MAI/AAAAAAAAAdI/mJcnzF3G-gM/s1600/the_most_beautiful_animal_1600x1200.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://wallup.net/wp-content/uploads/2016/01/155872-tiger-animals-nature.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://2.bp.blogspot.com/-NL_FTXIPipY/T-hZEw_vn8I/AAAAAAAAL5A/2IOPeIpdlNE/s1600/Tiger2.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download('cheetah animal', limit = 50, output_dir = dir, adult_filter_off = False)
# Out:
# [%] Downloading Images to /content/drive/MyDrive/image dataset/cheetah animal
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://1.bp.blogspot.com/-_BqqJlJ755Q/T_UzsDP1-VI/AAAAAAAAMU4/WC2_5HloyHk/s1600/Cheetah.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://1.bp.blogspot.com/-s3rKgPpsrq8/Tvx_HDljtdI/AAAAAAAAEDY/dOcQxz75hI0/s1600/cheetahs_1646474i4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://3.bp.blogspot.com/-5DL0D_N9nAQ/T5oZHuMS6LI/AAAAAAAAA8c/SCs_xuPwNvU/s1600/animals+big+cats+Female-Cheetah+hunting++masaimara+amboseli+serengeti+tsavo+on-the-Lookout+endangered+animal+picture.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://2.bp.blogspot.com/-gJVaEbOC49U/UNFJwJGlFYI/AAAAAAAAA50/ahWzXuSRzsU/s1600/cheetah+6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://4.bp.blogspot.com/-_f00jcPVwFE/T_Uz_O4H15I/AAAAAAAAMVY/Q1OtaA7xa_c/s1600/Cheetah5.jpg
# ...

# %%
downloader.download('lion animal', limit = 50, output_dir = dir, adult_filter_off = False)
# Out:
# [%] Downloading Images to /content/drive/MyDrive/image dataset/lion animal
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://2.bp.blogspot.com/-k1LTVxtn0Ls/UA5xzZv7o9I/AAAAAAAANNE/7Wg33Qnv-Aw/s1600/Lion5%2B-%2BCopy.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://wallpaperlepi.com/wp-content/uploads/2014/08/Lion-Animal-Wallpaper-PC.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://wallup.net/wp-content/uploads/2016/01/186050-lion-animals.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://www.digital-images.net/Images/WildAnimalPark/Lion_HS7149LGsigned.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://2.bp.blogspot.com/-xUhDTeNaeCY/UWk0hyEf0rI/AAAAAAAAAFk/kp79USw5ubE/s1600/Wild-Lion.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://wallup.net/wp-content/uploads/2016/01/15542-lion-animals.jpg
# [%] File Downloaded !
#
# ...
